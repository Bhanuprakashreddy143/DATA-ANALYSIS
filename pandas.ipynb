# %%
import pandas as pd
a=['Bhanu','Prakash','Sunny','Dhanush','Murthy','Satya','Sundar']
r=pd.Series(a,index=[60,55,85,96,98,99,23])
print(r)


df=pd.read_csv("/content/drive/MyDrive/Panda/diabetcsv.csv")
print(df)
# Out:
# 60      Bhanu
# 55    Prakash
# 85      Sunny
# 96    Dhanush
# 98     Murthy
# 99      Satya
# 23     Sundar
# dtype: object
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
hf=pd.read_csv("/content/grades_withnulls.csv", sep=" ")
print(hf)

print("  ")

df=pd.read_excel("/content/Catalogos.xlsx")
print(df)


df=pd.read_excel("/content/Catalogos.xlsx",sheet_name=2)
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 0                       Joe,K,9.8,10,9.9,A+,1
# 1                    Rajesh,M,8.9,9.1,9.3,A,1
# 2                     Kissan,V,9.9,9.8,10,A,0
# 3                        Mary,N,7.7,8,NaN,B,0
# 4                     Jeen,K,9.8,9.1,9.9,A+,1
# 5                       Raj,M,8.9,9.1,9.3,A,1
# 6                      Hassan,V,9.9,9,9.2,A,1
# 7                        Mari,N,7.7,8,7.1,B,1
# 8                     Jess,K,NaN,9.1,9.9,A+,1
# 9                    Rajini,M,NaN,9.1,9.3,A,0
# 10                    Kiran,V,NaN,9.3,9.2,A,0
# 11                       Maya,N,7.7,8,7.1,B,0
# 12                   Jolin,K,9.8,9.1,9.9,A+,1
# 13                   Rajesh,M,8.9,9.1,9.3,A,1
# 14                      Riya,M,9.3,9.9,10,A,1
# 15                     Sana,V,9.9,9.3,9.2,A,0
# 16                         Mark,N,7.7,8,7,B,0
#
#    CLAVE      DESCRIPCIÓN
# 0      1            USMER
# 1      2   FUERA DE USMER
# 2     99  NO ESPECIFICADO

# %%
df=pd.read_csv("/content/diabetcsv.csv")
print(df.head())
print(" ")
print(df.tail())
print(df.tail(n=10))
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
#
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
df=pd.read_csv("/content/diabetcsv.csv",sep=" ")
print(df.describe)

print(" ")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# <bound method NDFrame.describe of        preg,plas,pres,skin,insu,mass,pedi,age,class
# 0       6,148,72,35,0,33.6,0.627,50,tested_positive
# 1        1,85,66,29,0,26.6,0.351,31,tested_negative
# 2        8,183,64,0,0,23.3,0.672,32,tested_positive
# 3       1,89,66,23,94,28.1,0.167,21,tested_negative
# 4     0,137,40,35,168,43.1,2.288,33,tested_positive
# ..                                              ...
# 763  10,101,76,48,180,32.9,0.171,63,tested_negative
# 764      2,122,70,27,0,36.8,0.34,27,tested_negative
# 765   5,121,72,23,112,26.2,0.245,30,tested_negative
# 766      1,126,60,0,0,30.1,0.349,47,tested_positive
# 767      1,93,70,31,0,30.4,0.315,23,tested_negative
#
# [768 rows x 1 columns]>
#
# (768, 1)
# 768
# 1

# %%
df=pd.read_csv("/content/diabetcsv.csv")
df2=df.copy()
df2.loc[1:3,'preg']=None
df2.head(7)

print("   ")
print(df2)
print("  ")

print(df2.isnull().sum())
# Out:
#
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6.0   148    72    35     0  33.6  0.627   50  tested_positive
# 1     NaN    85    66    29     0  26.6  0.351   31  tested_negative
# 2     NaN   183    64     0     0  23.3  0.672   32  tested_positive
# 3     NaN    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0.0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763  10.0   101    76    48   180  32.9  0.171   63  tested_negative
# 764   2.0   122    70    27     0  36.8  0.340   27  tested_negative
# 765   5.0   121    72    23   112  26.2  0.245   30  tested_negative
# 766   1.0   126    60     0     0  30.1  0.349   47  tested_positive
# 767   1.0    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]
#
# preg     3
# plas     0
# pres     0
# skin     0
# insu     0
# mass     0
# pedi     0
# age      0
# class    0
# ...

# %%
df=pd.read_csv("/content/diabetcsv.csv")
print(df['preg'])

print(df[['preg','pres']])
print("  ")
print(df[df.index.isin(range(2,5))])
print("  ")
print(df.loc[1])
print("  ")
print(df.loc[3])
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: preg, Length: 768, dtype: int64
#      preg  pres
# 0       6    72
# 1       1    66
# 2       8    64
# 3       1    66
# 4       0    40
# ..    ...   ...
# 763    10    76
# 764     2    70
# 765     5    72
# 766     1    60
# 767     1    70
#
# [768 rows x 2 columns]
#
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
#
# preg                   1
# plas                  85
# pres                  66
# skin                  29
# insu                   0
# mass                26.6
# pedi               0.351
# age                   31
# class    tested_negative
# Name: 1, dtype: object
#
# preg                   1
# ...

# %%
df=pd.read_csv("/content/diabetcsv.csv")
print(df.loc[6:11])
print("   ")
df.loc[2:5,'pres']=0
print(df.loc[3:6])

print(" ")
print(df.loc[[1,5,8,9]])

df.loc[10:15,['preg','preg']]

print("  ")
df.loc[:7,["pres"]]
# Out:
#     preg  plas  pres  skin  insu  mass   pedi  age            class
# 6      3    78    50    32    88  31.0  0.248   26  tested_positive
# 7     10   115     0     0     0  35.3  0.134   29  tested_negative
# 8      2   197    70    45   543  30.5  0.158   53  tested_positive
# 9      8   125    96     0     0   0.0  0.232   54  tested_positive
# 10     4   110    92     0     0  37.6  0.191   30  tested_negative
# 11    10   168    74     0     0  38.0  0.537   34  tested_positive
#
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 3     1    89     0    23    94  28.1  0.167   21  tested_negative
# 4     0   137     0    35   168  43.1  2.288   33  tested_positive
# 5     5   116     0     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
#
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# ...

# %%
df=pd.read_csv("/content/diabetcsv.csv")
df[df.plas==88]
df[df.pres==66]

print("  ")
df.loc[df["class"]=="tested_positive"]
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# 6       3    78    50    32    88  31.0  0.248   26  tested_positive
# 8       2   197    70    45   543  30.5  0.158   53  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 755     1   128    88    39   110  36.5  1.057   37  tested_positive
# 757     0   123    72     0     0  36.3  0.258   52  tested_positive
# 759     6   190    92     0     0  35.5  0.278   66  tested_positive
# 761     9   170    74    31     0  44.0  0.403   43  tested_positive
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
#
# [268 rows x 9 columns]

# %%
df=pd.read_csv("/content/diabetcsv.csv")
df3=df.copy()
print(df3)

print("  ")
df3.dropna(inplace=True,axis=1)
df3
print("  ")
df3.dropna(inplace=True,how='all')
df3
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# ...

# %%
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn=pd.read_csv("/content/drive/MyDrive/Panda/grades_withnulls.csv")
print(dfn)
print(" ")
mv=dfn['SEM1'].mean()
dfn=dfn.fillna(mv)
print(dfn)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0
# ...
